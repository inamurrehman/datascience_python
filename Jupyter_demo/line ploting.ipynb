# %% [markdown]
# ## Import liberaries
# . numpy
# . scipy
# . pandas
# . matplotlib

# %%
import seaborn as sns
import matplotlib.pyplot as ptl
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
phool
#line plot
#sns.lineplot(x="", y= "", data=phool)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as ptl
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.lineplot(x="age", y= "fare", data=phool)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
import seaborn as sns
import matplotlib.pyplot as ptl
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.boxplot(x="age", y= "fare", data=phool)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
import seaborn as sns
import matplotlib.pyplot as ptl
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.barplot(x="age", y= "fare", data=phool)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
import seaborn as sns
import matplotlib.pyplot as ptl
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.catplot(x="age", y= "fare", data=phool)

# %%
import seaborn as sns
import matplotlib.pyplot as ptl
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.displot(x="age", y= "fare", data=phool)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.barplot(x="sex", y= "alone", hue= "who", data=phool, order=["female", "male"])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.barplot(x="sex", y= "alone", hue= "who", data=phool, order=["female", "male"], color= "gray")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.barplot(x="sex", y= "alone", hue= "who", data=phool, order=["female", "male"], color= "salmon")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.barplot(x="sex", y= "alone", hue= "who", data=phool, order=["female", "male"], color= "gray", ci= None)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.barplot(x="sex", y= "alone", hue= "who", data=phool, order=["female", "male"], color= "gray", ci=None, palette= "dark")
plt.show()

# %%
import seaborn as sns
#from numpy import mean #median
import numpy
import matplotlib.pyplot as plt
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.barplot(x="class", y= "fare", hue= "sex", data=phool, palette="bright", estimator = median)
plt.show()

# %%
import seaborn as sns
#from numpy import mean #median
import numpy
import matplotlib.pyplot as plt
#linestyle_tuple= [('loosely dotted', (0, (1,10)))]
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.lineplot(x="sex", y= "fare", data=phool, linestyle="dashed", color="red", palette="bright")
plt.show()

# %%
import seaborn as sns
#from numpy import mean #median
import numpy
import matplotlib.pyplot as plt
#linestyle_tuple= [('loosely dotted', (0, (1,10)))]
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.lineplot(x="sex", y= "fare", data=phool, linestyle="dashdot", color="blue", palette="bright")
plt.show()

# %%
import seaborn as sns
#from numpy import mean #median
import numpy
import matplotlib.pyplot as plt

phool=sns.load_dataset("titanic")

sns.lineplot(x="sex", y= "age", data=phool)
plt.title("line Plotting")
sns.set_style("dark")
sns.set_style(style=None, rc=None)
plt.show()

# %%
import seaborn as sns
#from numpy import mean #median
import numpy
import matplotlib.pyplot as plt
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.barplot(x="fare", y= "class", hue= "sex", data=phool, palette="bright", estimator = median)
plt.show()

# %%
import seaborn as sns
#from numpy import mean #median
import numpy
import matplotlib.pyplot as plt
#sns.get_dataset_names()
phool=sns.load_dataset("titanic")
#phool
#line plot
sns.barplot(x="class", y= "fare", hue= "sex", data=phool, linewidth=6, facecolor= (1,1,1,0.5), errcolor="0.2", edgecolor="0.3")
plt.show()
