# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
inam= pd.read_csv("Dataset1.csv")
inam
inam.head()

# %%
# Summary
inam.describe()
# Out:
#          Area Code  Element Code    Item Code  Year Code    Year         Value
# count    15.000000          15.0    15.000000       15.0    15.0  1.500000e+01
# mean   5300.000000        5157.0  3103.000000     2019.0  2019.0  1.256881e+07
# std     146.385011           0.0     0.845154        0.0     0.0  1.616631e+07
# min    5100.000000        5157.0  3102.000000     2019.0  2019.0  4.564997e+05
# 25%    5200.000000        5157.0  3102.000000     2019.0  2019.0  1.755160e+06
# 50%    5300.000000        5157.0  3103.000000     2019.0  2019.0  4.447679e+06
# 75%    5400.000000        5157.0  3104.000000     2019.0  2019.0  1.673660e+07
# max    5500.000000        5157.0  3104.000000     2019.0  2019.0  6.258450e+07

# %%
inam.head(2)
# Out:
#   Domain Code                   Domain  Area Code    Area  Element Code  \
# 0         RFN  Fertilizers by Nutrient       5100  Africa          5157
# 1         RFN  Fertilizers by Nutrient       5100  Africa          5157
#
#             Element  Item Code                             Item  Year Code  \
# 0  Agricultural Use       3102      Nutrient nitrogen N (total)       2019
# 1  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       2019
#
#    Year    Unit       Value Flag  \
# 0  2019  tonnes  4172357.06    A
# 1  2019  tonnes  1686657.71    A
#
#                                     Flag Description
# 0  Aggregate, may include official, semi-official...
# 1  Aggregate, may include official, semi-official...

# %%
#to drop columns 
# inam.drop(["Area Code", "Element"], axis=1)
#p= sns.color_palette("blue")
#Plot lineplot
sns.boxenplot(x="Year", y="Value",
              color="green",
              scale="linear", data=inam)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

kashti= sns.load_dataset("titanic")
kashti.mean()
kashti.describe()
# Out:
# C:\Users\inam\AppData\Local\Temp/ipykernel_2660/1786614896.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   kashti.mean()
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# ...

# %%
kashti[kashti["age"] < 18].groupby(['sex', 'class']).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.875000     1.0  14.125000  0.500000  0.875000  104.083337
#        Second  1.000000     2.0   8.333333  0.583333  1.083333   26.241667
#        Third   0.542857     3.0   8.428571  1.571429  1.057143   18.727977
# male   First   1.000000     1.0   8.230000  0.500000  2.000000  116.072900
#        Second  0.818182     2.0   4.757273  0.727273  1.000000   25.659473
#        Third   0.232558     3.0   9.963256  2.069767  1.000000   22.752523
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.125000
#        Second    0.000000  0.166667
#        Third     0.000000  0.228571
# male   First     0.250000  0.000000
#        Second    0.181818  0.181818
#        Third     0.348837  0.232558

# %%
kashti[kashti["age"] < 18].groupby(['sex', 'class']).mean()

# %%
kashti.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
kashti.mean()
# Out:
# C:\Users\inam\AppData\Local\Temp/ipykernel_2660/3332994036.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   kashti.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
kashti.mode()
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  24.0      0      0  8.05        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True    C  Southampton    no   True

# %%
kashti.median()
# Out:
# C:\Users\inam\AppData\Local\Temp/ipykernel_2660/854433089.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   kashti.median()
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64
